# %% [markdown]
# # Assignment 3

# %% [markdown]
# ## Pandas and plotting exercises

# %%
# Import the pandas library
import pandas as pd

# %% [markdown]
# In Week 2, you used a dataset from the CORGIS website.  You may have used either the Python, CSV, or JSON data files.
#
# For this assignment, use the CSV file format for the same category of data that you used previously.

# %%
# Use pandas read_csv function to import the data into a dataframe variable
df = pd.read_csv('broadway.csv')
df
# Out:
#        Date.Day  Date.Full  Date.Month  Date.Year                 Show.Name  \
# 0            26  8/26/1990           8       1990                       Tru
# 1            24  3/24/1991           3       1991               Miss Saigon
# 2            31  3/31/1991           3       1991               Miss Saigon
# 3             7   4/7/1991           4       1991               Miss Saigon
# 4            14  4/14/1991           4       1991               Miss Saigon
# ...         ...        ...         ...        ...                       ...
# 31291        14  8/14/2016           8       2016                The Humans
# 31292        14  8/14/2016           8       2016             The Lion King
# 31293        14  8/14/2016           8       2016  The Phantom Of The Opera
# 31294        14  8/14/2016           8       2016                  Waitress
# 31295        14  8/14/2016           8       2016                    Wicked
#
#           Show.Theatre Show.Type  Statistics.Attendance  Statistics.Capacity  \
# 0                Booth      Play                   5500                   88
# 1             Broadway   Musical                   1737                  100
# 2             Broadway   Musical                  12160                  100
# 3             Broadway   Musical                  13921                  100
# 4             Broadway   Musical                  10973                   90
# ...                ...       ...                    ...                  ...
# 31291       Schoenfeld      Play                   7234                   87
# 31292         Minskoff   Musical                  13485                   99
# 31293         Majestic   Musical                  10966                   85
# 31294  Brooks Atkinson   Musical                   8058                   96
# 31295         Gershwin   Musical                  13804                   95
#
#        Statistics.Gross  Statistics.Gross Potential  Statistics.Performances
# 0                134456                           0                        8
# 1                100647                           0                        0
# 2                634424                           0                        0
# 3                713353                           0                        0
# 4                573981                           0                        4
# ...                 ...                         ...                      ...
# 31291            603770                          62                        8
# 31292           2233894                          97                        8
# 31293            999632                          66                        8
# 31294            990128                          97                        8
# 31295           1779664                         100                        8
#
# [31296 rows x 12 columns]

# %%
# How many rows and columns does the dataframe have?
row, col = df.shape
print("The dataframe has", row, "rows.")
print("The dataframe has", col, "columns.")
# Out:
# The dataframe has 31296 rows.
# The dataframe has 12 columns.

# %%
# What are the column names of the dataframe?
df.columns
# Out:
# Index(['Date.Day', 'Date.Full', 'Date.Month', 'Date.Year', 'Show.Name',
#        'Show.Theatre', 'Show.Type', 'Statistics.Attendance',
#        'Statistics.Capacity', 'Statistics.Gross', 'Statistics.Gross Potential',
#        'Statistics.Performances'],
#       dtype='object')

# %%
# What are the datatypes of each column?
df.dtypes
# Out:
# Date.Day                       int64
# Date.Full                     object
# Date.Month                     int64
# Date.Year                      int64
# Show.Name                     object
# Show.Theatre                  object
# Show.Type                     object
# Statistics.Attendance          int64
# Statistics.Capacity            int64
# Statistics.Gross               int64
# Statistics.Gross Potential     int64
# Statistics.Performances        int64
# dtype: object

# %%
# Look at the first 2 rows of the dataframe
df.head(2)
# Out:
#    Date.Day  Date.Full  Date.Month  Date.Year    Show.Name Show.Theatre  \
# 0        26  8/26/1990           8       1990          Tru        Booth
# 1        24  3/24/1991           3       1991  Miss Saigon     Broadway
#
#   Show.Type  Statistics.Attendance  Statistics.Capacity  Statistics.Gross  \
# 0      Play                   5500                   88            134456
# 1   Musical                   1737                  100            100647
#
#    Statistics.Gross Potential  Statistics.Performances
# 0                           0                        8
# 1                           0                        0

# %%
# Look at the last 2 rows of the dataframe
df.tail(2)
# Out:
#        Date.Day  Date.Full  Date.Month  Date.Year Show.Name     Show.Theatre  \
# 31294        14  8/14/2016           8       2016  Waitress  Brooks Atkinson
# 31295        14  8/14/2016           8       2016    Wicked         Gershwin
#
#       Show.Type  Statistics.Attendance  Statistics.Capacity  Statistics.Gross  \
# 31294   Musical                   8058                   96            990128
# 31295   Musical                  13804                   95           1779664
#
#        Statistics.Gross Potential  Statistics.Performances
# 31294                          97                        8
# 31295                         100                        8

# %%
# Print out summary statistics about the dataframe
df.describe(include='all')
# Out:
#             Date.Day  Date.Full    Date.Month     Date.Year  \
# count   31296.000000      31296  31296.000000  31296.000000
# unique           NaN       1327           NaN           NaN
# top              NaN  4/22/2012           NaN           NaN
# freq             NaN         39           NaN           NaN
# mean       15.720859        NaN      6.509043   2005.875128
# std         8.817000        NaN      3.430321      6.100118
# min         1.000000        NaN      1.000000   1990.000000
# 25%         8.000000        NaN      4.000000   2001.000000
# 50%        16.000000        NaN      6.000000   2006.000000
# 75%        23.000000        NaN     10.000000   2011.000000
# max        31.000000        NaN     12.000000   2016.000000
#
#                        Show.Name Show.Theatre Show.Type  \
# count                      31296        31296     31296
# unique                       820           56         3
# top     The Phantom Of The Opera     Majestic   Musical
# freq                        1053         1053     22551
# mean                         NaN          NaN       NaN
# std                          NaN          NaN       NaN
# min                          NaN          NaN       NaN
# 25%                          NaN          NaN       NaN
# 50%                          NaN          NaN       NaN
# 75%                          NaN          NaN       NaN
# max                          NaN          NaN       NaN
#
#         Statistics.Attendance  Statistics.Capacity  Statistics.Gross  \
# count            31296.000000         31296.000000      3.129600e+04
# unique                    NaN                  NaN               NaN
# top                       NaN                  NaN               NaN
# freq                      NaN                  NaN               NaN
# mean              8010.523006            80.738912      5.960688e+05
# std               3189.873933            18.842815      3.809796e+05
# min                 24.000000            10.000000      1.037000e+03
# 25%               5508.000000            70.000000      3.201085e+05
# 50%               7801.500000            83.000000      5.145200e+05
# 75%              10348.000000            95.000000      7.852690e+05
# max              21631.000000           892.000000      3.201333e+06
#
#         Statistics.Gross Potential  Statistics.Performances
# count                 31296.000000             31296.000000
# unique                         NaN                      NaN
# top                            NaN                      NaN
# freq                           NaN                      NaN
# mean                     62.404045                 7.224821
# std                      28.714589                 2.235376
# min                       0.000000                 0.000000
# 25%                      45.000000                 8.000000
# 50%                      63.000000                 8.000000
# 75%                      82.000000                 8.000000
# max                     226.000000                16.000000

# %%
# Choose a column and print out the column (it's ok if the output is abbreviated)
df['Show.Name']
# Out:
# 0                             Tru
# 1                     Miss Saigon
# 2                     Miss Saigon
# 3                     Miss Saigon
# 4                     Miss Saigon
#                    ...
# 31291                  The Humans
# 31292               The Lion King
# 31293    The Phantom Of The Opera
# 31294                    Waitress
# 31295                      Wicked
# Name: Show.Name, Length: 31296, dtype: object

# %%
# Choose a column that has numeric values and make a line plot of the values
a = df['Statistics.Capacity']
a.plot(kind='line')
# Out:
# <AxesSubplot:>

# %%
# Use "loc" to print out the first 10 elements of the plotted column
df.loc[range(0,10),['Statistics.Capacity']]
# Out:
#    Statistics.Capacity
# 0                   88
# 1                  100
# 2                  100
# 3                  100
# 4                   90
# 5                  101
# 6                  101
# 7                  101
# 8                  100
# 9                   99

# %%
# Use "loc" to print out the first 10 elements of the plotted column
# as well as the matching 10 elements of a different column that has interesting text
df.loc[range(0,10),['Statistics.Capacity', 'Show.Theatre']]
# Out:
#    Statistics.Capacity Show.Theatre
# 0                   88        Booth
# 1                  100     Broadway
# 2                  100     Broadway
# 3                  100     Broadway
# 4                   90     Broadway
# 5                  101     Broadway
# 6                  101     Broadway
# 7                  101     Broadway
# 8                  100     Broadway
# 9                   99     Broadway

# %%
# Assign the dataframe values from the previous cell into a new dataframe variable
# and make a bar plot with the text values horizontally and the numeric values as the bar heights
theaters = df.loc[range(0,10),['Statistics.Capacity', 'Show.Theatre']]
theaters.plot(kind='bar', x='Show.Theatre', y='Statistics.Capacity')
# Out:
# <AxesSubplot:xlabel='Show.Theatre'>

# %%
# Re-do the plot from the previous cell as a horizontal bar plot
theaters.plot(kind='barh', x='Show.Theatre', y='Statistics.Capacity')
# Out:
# <AxesSubplot:ylabel='Show.Theatre'>

# %%
# Re-do the plot from the previous cell
# and change at least two aesthetic elements (colors, labels, titles, ...)
barcolors = []
for i in range(0,10):
    if i%2:
        barcolors.append('grey')
    else:
        barcolors.append('orange')

ax = theaters.plot(kind='barh', 
              x='Show.Theatre', 
              y='Statistics.Capacity',
              color=barcolors
             )
ax.set_title('Broadway Theatres Capacity')
ax.set_xlabel('Capacity',fontsize=14)
ax.set_ylabel('Theatre',fontsize=14)
# Out:
# Text(0, 0.5, 'Theatre')

# %% [markdown]
# # Free form section

# %% [markdown]
# * Choose another type of plot that interests you from the [pandas.DataFrame.plot documentation](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html#) [look at the 'kind' parameter] and make a new plot of your dataset values using the plot type

# %%
df.groupby('Show.Theatre')[['Statistics.Gross', 'Statistics.Capacity']].mean().plot(kind='scatter', x='Statistics.Capacity', y='Statistics.Gross')
# Out:
# <AxesSubplot:xlabel='Statistics.Capacity', ylabel='Statistics.Gross'>

# %% [markdown]
# * Copy some of your analysis from the Week 2 assignment into new cells below
# * Clean them up if desired, and make sure that you translate them to work with your new pandas dataframe structure here if needed
# * Create several plots to complement and extend your analysis

# %%
# Mathemtical operation
shows = df['Show.Name'].unique()
shows

# Mathemtical operation
total_attendance = {}
for index,row in df.iterrows():
    show = row['Show.Name']
    if show not in total_attendance:
        total_attendance[show] = 0
    total_attendance[show] += row['Statistics.Attendance']

att = pd.DataFrame.from_dict(total_attendance, orient='index')
att
# Out:
#                                    0
# Tru                             5500
# Miss Saigon                  5843972
# A Streetcar Named Desire 92   146568
# The Sisters Rosensweig        510634
# Beauty And The Beast         7609397
# ...                              ...
# Tuck Everlasting               59117
# Paramour                      182511
# An Act Of God 2016             44188
# Cats 2016                      43019
# Motown The Musical 2016        19902
#
# [820 rows x 1 columns]

# %%
att.plot(kind='bar', figsize=(100,5))
# Out:
# <AxesSubplot:>

# %%
after_2010 = df[df['Date.Year'] >= 2010].groupby('Date.Year').count()
after_2010.plot(kind='bar', y='Statistics.Performances').set_title('Number of Broadway Performances every year after 2010')
# Out:
# Text(0.5, 1.0, 'Number of Broadway Performances every year after 2010')
